# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = yf.download("AAPL", start="2020-01-01", end="2021-01-01")
data.columns
data.head()
data.Close
# Out:
# /var/folders/p3/6pb747392sqb5mql2qlg15qc0000gn/T/ipykernel_26927/3759084987.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("AAPL", start="2020-01-01", end="2021-01-01")
# [*********************100%***********************]  1 of 1 completed
# Ticker            AAPL
# Date
# 2020-01-02   72.538513
# 2020-01-03   71.833290
# 2020-01-06   72.405678
# 2020-01-07   72.065163
# 2020-01-08   73.224426
# ...                ...
# 2020-12-24  128.591019
# 2020-12-28  133.190170
# 2020-12-29  131.416794
# 2020-12-30  130.296219
# 2020-12-31  129.292587
#
# [253 rows x 1 columns]

# %%
plt.figure(figsize = (15,10))
plt.plot(data["Close"],label="AAPL CLOSING PRICE")
plt.title("STOCK (AAPL) PRICE -- 2020-2021")
plt.xlabel("Date")
plt.ylabel("Price in $")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
