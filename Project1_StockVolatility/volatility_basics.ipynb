# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = yf.download("AAPL", start="2007-02-01", end="2009-01-01")
#data.columns
#data.head()
#data.Close
# Out:
# /var/folders/p3/6pb747392sqb5mql2qlg15qc0000gn/T/ipykernel_6478/3402423401.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("AAPL", start="2007-02-01", end="2009-01-01")
# [*********************100%***********************]  1 of 1 completed

# %%
plt.figure(figsize = (15,10))
plt.plot(data["Close"],label="AAPL CLOSING PRICE")
plt.title("STOCK (AAPL) PRICE -- 2007-2009")
plt.xlabel("Date")
plt.ylabel("Price in $")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Daily return of AAPL stock
data['returns'] = data["Close"].pct_change()+1
plt.figure(figsize = (10,6))
plt.plot(data['returns'], label = 'Daily AAPL stock retruns')
plt.title('Daily Returns of AAPL stock', size = 18)
plt.legend()
plt.show()

# %%
#Cummulative return of APPL stock
data['cumulative_returns'] = data['Close']/data['Close'].iloc[0]
plt.figure(figsize = (10,6))
plt.plot(data['cumulative_returns'], label = 'Cumulative AAPL stock retruns')
plt.title('Cumulative Returns of AAPL stock', size = 18)
plt.legend()
plt.show()
# In Oct 2008 one can observe the highest volatility in the 2 year window.

# %%
 #Computing Volatility of stock  := std of log return of stock
#First, compute log return
logreturn = np.log(data['returns'])
#Next, compute yearly std 
np.std(logreturn)*np.sqrt(252)
# Out:
# np.float64(0.49780172389173316)
